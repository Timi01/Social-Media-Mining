# %% [markdown]
# # Mining Twitter

# %% [markdown]
# ## Exploring Trending Topics, Discovering What People Are Talking About, and More

# %% [markdown]
# ### Authorizing an application to access Twitter account data

# %%
import twitter

# %%
import twitter
from twitter import *

# %%
CONSUMER_KEY = ''
CONSUMER_SECRET = ''
OAUTH_TOKEN = ''
OAUTH_TOKEN_SECRET = ''

auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,CONSUMER_KEY, CONSUMER_SECRET)
twitter_api = twitter.Twitter(auth=auth)

print (twitter_api)

# %% [markdown]
# ### Retrieving trends

# %%
WORLD_WOE_ID = 1
US_WOE_ID = 23424977

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)

# %%
print (world_trends)
# Out:
# [{'trends': [{'name': '#كلمه_تسعدك_كثير', 'url': 'http://twitter.com/search?q=%23%D9%83%D9%84%D9%85%D9%87_%D8%AA%D8%B3%D8%B9%D8%AF%D9%83_%D9%83%D8%AB%D9%8A%D8%B1', 'promoted_content': None, 'query': '%23%D9%83%D9%84%D9%85%D9%87_%D8%AA%D8%B3%D8%B9%D8%AF%D9%83_%D9%83%D8%AB%D9%8A%D8%B1', 'tweet_volume': 10359}, {'name': '#شعورك_حاليا_في_تغريده', 'url': 'http://twitter.com/search?q=%23%D8%B4%D8%B9%D9%88%D8%B1%D9%83_%D8%AD%D8%A7%D9%84%D9%8A%D8%A7_%D9%81%D9%8A_%D8%AA%D8%BA%D8%B1%D9%8A%D8%AF%D9%87', 'promoted_content': None, 'query': '%23%D8%B4%D8%B9%D9%88%D8%B1%D9%83_%D8%AD%D8%A7%D9%84%D9%8A%D8%A7_%D9%81%D9%8A_%D8%AA%D8%BA%D8%B1%D9%8A%D8%AF%D9%87', 'tweet_volume': 53037}, {'name': '#ÇağıAydınlatanKadınlar', 'url': 'http://twitter.com/search?q=%23%C3%87a%C4%9F%C4%B1Ayd%C4%B1nlatanKad%C4%B1nlar', 'promoted_content': None, 'query': '%23%C3%87a%C4%9F%C4%B1Ayd%C4%B1nlatanKad%C4%B1nlar', 'tweet_volume': 20668}, {'name': '花火大会', 'url': 'http://twitter.com/search?q=%E8%8A%B1%E7%81%AB%E5%A4%A7%E4%B
# ...

# %%
print (us_trends)
# Out:
# [{'trends': [{'name': '#BlockedIn5WordsOrLess', 'url': 'http://twitter.com/search?q=%23BlockedIn5WordsOrLess', 'promoted_content': None, 'query': '%23BlockedIn5WordsOrLess', 'tweet_volume': None}, {'name': '#HowIThankSomeone', 'url': 'http://twitter.com/search?q=%23HowIThankSomeone', 'promoted_content': None, 'query': '%23HowIThankSomeone', 'tweet_volume': None}, {'name': '#SaturdayMorning', 'url': 'http://twitter.com/search?q=%23SaturdayMorning', 'promoted_content': None, 'query': '%23SaturdayMorning', 'tweet_volume': 14389}, {'name': '#TeamWorld', 'url': 'http://twitter.com/search?q=%23TeamWorld', 'promoted_content': None, 'query': '%23TeamWorld', 'tweet_volume': None}, {'name': '#BeachToBeacon', 'url': 'http://twitter.com/search?q=%23BeachToBeacon', 'promoted_content': None, 'query': '%23BeachToBeacon', 'tweet_volume': None}, {'name': 'Don Lemon', 'url': 'http://twitter.com/search?q=%22Don+Lemon%22', 'promoted_content': None, 'query': '%22Don+Lemon%22', 'tweet_volume': 50866}, {'n
# ...

# %% [markdown]
# ### Displaying API responses as pretty-printed JSON

# %%
import json

# %%
print (json.dumps(world_trends, indent=1))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "#\u0643\u0644\u0645\u0647_\u062a\u0633\u0639\u062f\u0643_\u0643\u062b\u064a\u0631",
#     "url": "http://twitter.com/search?q=%23%D9%83%D9%84%D9%85%D9%87_%D8%AA%D8%B3%D8%B9%D8%AF%D9%83_%D9%83%D8%AB%D9%8A%D8%B1",
#     "promoted_content": null,
#     "query": "%23%D9%83%D9%84%D9%85%D9%87_%D8%AA%D8%B3%D8%B9%D8%AF%D9%83_%D9%83%D8%AB%D9%8A%D8%B1",
#     "tweet_volume": 10359
#    },
#    {
#     "name": "#\u0634\u0639\u0648\u0631\u0643_\u062d\u0627\u0644\u064a\u0627_\u0641\u064a_\u062a\u063a\u0631\u064a\u062f\u0647",
#     "url": "http://twitter.com/search?q=%23%D8%B4%D8%B9%D9%88%D8%B1%D9%83_%D8%AD%D8%A7%D9%84%D9%8A%D8%A7_%D9%81%D9%8A_%D8%AA%D8%BA%D8%B1%D9%8A%D8%AF%D9%87",
#     "promoted_content": null,
#     "query": "%23%D8%B4%D8%B9%D9%88%D8%B1%D9%83_%D8%AD%D8%A7%D9%84%D9%8A%D8%A7_%D9%81%D9%8A_%D8%AA%D8%BA%D8%B1%D9%8A%D8%AF%D9%87",
#     "tweet_volume": 53037
#    },
#    {
#     "name": "#\u00c7a\u011f\u0131Ayd\u0131nlatanKad\u0131nlar",
# ...

# %%
print (json.dumps(us_trends, indent=1))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "#BlockedIn5WordsOrLess",
#     "url": "http://twitter.com/search?q=%23BlockedIn5WordsOrLess",
#     "promoted_content": null,
#     "query": "%23BlockedIn5WordsOrLess",
#     "tweet_volume": null
#    },
#    {
#     "name": "#HowIThankSomeone",
#     "url": "http://twitter.com/search?q=%23HowIThankSomeone",
#     "promoted_content": null,
#     "query": "%23HowIThankSomeone",
#     "tweet_volume": null
#    },
#    {
#     "name": "#SaturdayMorning",
#     "url": "http://twitter.com/search?q=%23SaturdayMorning",
#     "promoted_content": null,
#     "query": "%23SaturdayMorning",
#     "tweet_volume": 14389
#    },
#    {
#     "name": "#TeamWorld",
#     "url": "http://twitter.com/search?q=%23TeamWorld",
#     "promoted_content": null,
#     "query": "%23TeamWorld",
#     "tweet_volume": null
#    },
#    {
#     "name": "#BeachToBeacon",
#     "url": "http://twitter.com/search?q=%23BeachToBeacon",
#     "promoted_content": null,
# ...

# %% [markdown]
# ### Computing the intersection of two sets of trends

# %%
world_trends_set = set([trend['name']
                        for trend in world_trends[0]['trends']])

us_trends_set = set([trend['name']
                     for trend in us_trends[0]['trends']])

# %%
print(us_trends_set)
# Out:
# {'#EVO2018', '#CzechGP', 'Johnny Manziel', 'Urban Meyer', '#LivePD', '#VuduViewingParty', 'Don Lemon', '#Lollapalooza', 'David Goffin', '#DreDay', 'Rick Porcello', 'Andrew Sullivan', '#OneGoal', '#FilmsInRealTime', '#INDvsENG', '#friyay', '#SocialMediaSurvivalTips', 'Zach Smith', 'Yoongi', 'I Like Mike', '#MonstaXinLA', '#BlockedIn5WordsOrLess', 'The Children', '#CriticalRole', '#TeamWorld', 'DACA', 'Wade Davis', '#InMyRetirement', '#SaturdayMorning', '#PMC2018', '#HowIThankSomeone', 'Christopher Robin', '#NationalWatermelonDay', '#NN18', '#BeachToBeacon', '#facebookdown', 'Cory Booker', '#NewMusicFriday', '#InternationalBeerDay', '#AHSApocalypse', '#AndThatsWhyImBroke', '#HarryPotterABand', '#GSLvsTHEWORLD', '#UFC229', '#WynonnaEarp', '#ASTROWORLD', 'Bill Maher', 'Travis Scott'}

# %%
print(world_trends_set)
# Out:
# {'花火の音', '#شعورك_حاليا_في_تغريده', '#كلمه_تسعدك_كثير', '#GWKwonderfulindonesia', '#اكتشاف_المياه_باحدث_الاجهزه', '#مقوله_الاقارب_عقارب', '#MissGrannyPHTourAyalaFeliz', '#KishoreKumar', '#AmsterdamPride', '#4agosto', '#EyesonYouinSG', '#みくるサマー', '#AFLSwansPies', '#PSGASM', 'Ben Stokes', 'Ishant', '#BrightonPride', "Hakkari Yüksekova'da", 'UygunFiyatlı TtVerilirr', '#جوناس_حق_النصر', '#EnverPaşa', 'Pandya', '#ÇağıAydınlatanKadınlar', '#vaccini', '淀川花火', '#PersibDay', '#AFLCrowsPower', '#BlockedIn5WordsOrLess', 'Cuando Franco', '#SabadoDetremuraSDV', '#BuenSabado', '#رساله_لامك_الغاليه', '#NRLRoostersCowboys', '#HowIThankSomeone', '#AFLSaintsDogs', '#هل_الهديه_ترضي_الزعلان', '花火大会', 'Łukasz Piszczek', '#EnİyiMeslek', '#كشف_ملابسات_قضيه_هدو', '#TurgutUyar', '#VASC', '#MetroLovesKathNiel', '#CRUvLIO', '#FelizSábado', '#REDMAREinSEOUL_Day1', '#PiKONICDAY', '#音MDM', '#انا_من_جيل_ال_كان', '#SaturdayMorning'}

# %%
common_trends = world_trends_set.intersection(us_trends_set)
print (common_trends)
# Out:
# {'#HowIThankSomeone', '#BlockedIn5WordsOrLess', '#SaturdayMorning'}

# %% [markdown]
# ### Get all the locations where Twitter provides trends service

# %%
locations = twitter_api.trends.available(_woeid=1)

# %%
locations
# Out:
# [{'country': '',
#   'countryCode': None,
#   'name': 'Worldwide',
#   'parentid': 0,
#   'placeType': {'code': 19, 'name': 'Supername'},
#   'url': 'http://where.yahooapis.com/v1/place/1',
#   'woeid': 1},
#  {'country': 'Canada',
#   'countryCode': 'CA',
#   'name': 'Winnipeg',
#   'parentid': 23424775,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/2972',
#   'woeid': 2972},
#  {'country': 'Canada',
#   'countryCode': 'CA',
#   'name': 'Ottawa',
#   'parentid': 23424775,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/3369',
#   'woeid': 3369},
#  {'country': 'Canada',
#   'countryCode': 'CA',
#   'name': 'Quebec',
#   'parentid': 23424775,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/3444',
#   'woeid': 3444},
#  {'country': 'Canada',
#   'countryCode': 'CA',
#   'name': 'Montreal',
#   'parentid': 23424775,
# ...

# %%
country_set = set(i['country'] for i in locations)

# %%
print(country_set)
# Out:
# {'', 'United Kingdom', 'Netherlands', 'Singapore', 'Argentina', 'Ghana', 'Sweden', 'Greece', 'Jordan', 'Pakistan', 'Algeria', 'Thailand', 'Belarus', 'Portugal', 'Dominican Republic', 'Latvia', 'Korea', 'Chile', 'Israel', 'Kuwait', 'Peru', 'France', 'Italy', 'United States', 'India', 'Qatar', 'Turkey', 'Saudi Arabia', 'Nigeria', 'Guatemala', 'Germany', 'Malaysia', 'Switzerland', 'Mexico', 'Norway', 'Lebanon', 'Ukraine', 'Ireland', 'Japan', 'Indonesia', 'Vietnam', 'Colombia', 'Ecuador', 'South Africa', 'Panama', 'Oman', 'Canada', 'Venezuela', 'Denmark', 'Brazil', 'Spain', 'Russia', 'Kenya', 'Austria', 'Belgium', 'New Zealand', 'Puerto Rico', 'Bahrain', 'Poland', 'Philippines', 'Egypt', 'United Arab Emirates', 'Australia'}

# %%
locations_set = set(i['name'] for i in locations)

# %%
print(locations_set)
# Out:
# {'Okayama', 'Argentina', 'Ghana', 'Italy', 'Saint Petersburg', 'Accra', 'Dammam', 'Las Palmas', 'Sharjah', 'Indianapolis', 'Kajang', 'Bristol', 'Nashville', 'Morelia', 'Colorado Springs', 'São Paulo', 'Vietnam', 'Adelaide', 'Hyderabad', 'Petaling', 'Belgium', 'Chihuahua', 'Albuquerque', 'Mendoza', 'Turin', 'Dubai', 'Thailand', 'Bekasi', 'Aguascalientes', 'Zamboanga City', 'Baltimore', 'Guatemala', 'Kyiv', 'Switzerland', 'Amman', 'Mexico', 'Norway', 'Montreal', 'Paris', 'Indonesia', 'Phoenix', 'Alexandria', 'Denmark', 'Mecca', 'Zurich', 'Vancouver', 'Palermo', 'New Zealand', 'Atlanta', 'Ho Chi Minh City', 'Genoa', 'Singapore', 'Netherlands', 'Sendai', 'Sweden', 'Frankfurt', 'Guayaquil', 'Birmingham', 'Winnipeg', 'Munich', 'Seoul', 'Riga', 'Culiacán', 'Seongnam', 'Guadalajara', 'Campinas', 'Nottingham', 'San Jose', 'Ireland', 'Rome', 'Quebec', 'Port Harcourt', 'Athens', 'Brazil', 'Moscow', 'Mesa', 'Lagos', 'Fresno', 'Bremen', 'Austin', 'Brest', 'Istanbul', 'Krasnoyarsk', 'El Paso', 'Be
# ...

# %% [markdown]
# ### Collecting search results

# %%
# Set variable 'q' to a trending topic

q = '#deeplearning'
count = 100

search_results = twitter_api.search.tweets(q=q, count=count)
statuses = search_results['statuses']

# %%
# Iterate through 5 more batches of results by following the cursor

for _ in range(5):
    print ("Length of statuses", len(statuses))
    try:
        next_results = search_results['search_metadata']['next_results']
    except KeyError as e: # No more results when next_results doesn't exist
        break
        
# Create a dictionary from next_results, which has the following form:?max_id=313519052523986943&q=NCAA&include_entities=1

    kwargs = dict([ kv.split('=') for kv in next_results[1:].split("&") ])
    search_results = twitter_api.search.tweets(**kwargs)
    statuses += search_results['statuses']
# Out:
# Length of statuses 100
# Length of statuses 200
# Length of statuses 200

# %%
# Show one sample search result by slicing the list...
print (json.dumps(statuses[0], indent=1))
# Out:
# {
#  "created_at": "Sat Aug 04 11:23:52 +0000 2018",
#  "id": 1025703862143995905,
#  "id_str": "1025703862143995905",
#  "text": "RT @ipfconline1: The 4 Types of Artificial Intelligence: From Reactive to Self-Aware [Infographic]\n\nhttps://t.co/AgXBj9Aeir      v/ @Futuri\u2026",
#  "truncated": false,
#  "entities": {
#   "hashtags": [],
#   "symbols": [],
#   "user_mentions": [
#    {
#     "screen_name": "ipfconline1",
#     "name": "ipfconline",
#     "id": 705539763349164032,
#     "id_str": "705539763349164032",
#     "indices": [
#      3,
#      15
#     ]
#    }
#   ],
#   "urls": [
#    {
#     "url": "https://t.co/AgXBj9Aeir",
#     "expanded_url": "http://buff.ly/2uRRp70",
#     "display_url": "buff.ly/2uRRp70",
#     "indices": [
#      100,
#      123
#     ]
#    }
#   ]
#  },
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
# ...

# %%
# Printing the status
for status in statuses:
    print (status['text'])
# Out:
# RT @ipfconline1: The 4 Types of Artificial Intelligence: From Reactive to Self-Aware [Infographic]
#
# https://t.co/AgXBj9Aeir      v/ @Futuri…
# RT @KirkDBorne: Comprehensive Repository of #DataScience and #MachineLearning Resources, including “22 Informative Articles About #NeuralNe…
# RT @Shavonda2016: How Executives use Social Media via #SocialCastInc
#
# #SEO #DigitalMarketing #ContentMarketing #Marketing #SMM #IoT #Growt…
# RT @marcusborba: Great! Simple object tracking with OpenCV’s deep learning face detector (w/ Py code) https://t.co/UdOEcO5ms8 via @PyImageS…
# RT @SocialWiz: Where would we be without the #Internet? Scary thought! But DO YOU KNOW where the internet 'comes from'? VIA @Orcanintell
#
# #…
# RT @AnalyticsVidhya: You'll be simply amazed to explore #PyTorch - simple yet powerful #deeplearning library, most flexible &amp; easy to grasp…
# ...

# %%
# You can then dump your json data into a file for later analysis in this manner:
with open('status.txt', 'w') as outfile:
    json.dump(statuses, outfile)

# %% [markdown]
# ## Analyzing the 140 Characters

# %% [markdown]
# ### Extracting text, screen names, and hashtags from tweets

# %%
status_texts = [i['text'] for i in statuses]

# %%
status_texts[0]
# Out:
# 'RT @ipfconline1: The 4 Types of Artificial Intelligence: From Reactive to Self-Aware [Infographic]\n\nhttps://t.co/AgXBj9Aeir      v/ @Futuri…'

# %%
import pandas as pd

# %%
tweeter = pd.DataFrame(status_texts, columns = ['tweet'])

# %%
tweeter.head()
# Out:
#                                                tweet
# 0  RT @ipfconline1: The 4 Types of Artificial Int...
# 1  RT @KirkDBorne: Comprehensive Repository of #D...
# 2  RT @Shavonda2016: How Executives use Social Me...
# 3  RT @marcusborba: Great! Simple object tracking...
# 4  RT @SocialWiz: Where would we be without the #...

# %%
screen_names = [user_mention['screen_name']
                    for status in statuses
                       for user_mention in status['entities']['user_mentions']]

# %%
tweeter['names'] = pd.DataFrame(screen_names)

# %%
tweeter.head()
# Out:
#                                                tweet         names
# 0  RT @ipfconline1: The 4 Types of Artificial Int...   ipfconline1
# 1  RT @KirkDBorne: Comprehensive Repository of #D...    KirkDBorne
# 2  RT @Shavonda2016: How Executives use Social Me...  Shavonda2016
# 3  RT @marcusborba: Great! Simple object tracking...   marcusborba
# 4  RT @SocialWiz: Where would we be without the #...     SocialWiz

# %%
hashtags = [hashtag['text']
              for status in statuses
                  for hashtag in status['entities']['hashtags']]

# %%
tweeter['hashtag'] = pd.DataFrame(hashtags)

# %%
tweeter.head()
# Out:
#                                                tweet         names  \
# 0  RT @ipfconline1: The 4 Types of Artificial Int...   ipfconline1
# 1  RT @KirkDBorne: Comprehensive Repository of #D...    KirkDBorne
# 2  RT @Shavonda2016: How Executives use Social Me...  Shavonda2016
# 3  RT @marcusborba: Great! Simple object tracking...   marcusborba
# 4  RT @SocialWiz: Where would we be without the #...     SocialWiz
#
#             hashtag
# 0       DataScience
# 1   MachineLearning
# 2     SocialCastInc
# 3               SEO
# 4  DigitalMarketing

# %%
tweeter.to_csv('tweeter.csv', index = False)

# %%
# Compute the collection of all words from all tweets

words = [w
            for t in status_texts
                for w in t.split()]

# %%
# Explore the first 5 items for each...

print (json.dumps(status_texts[0:5], indent=1))
print (json.dumps(screen_names[0:5], indent=1))
print (json.dumps(hashtags[0:5], indent=1))
print (json.dumps(words[0:5], indent=1))
# Out:
# [
#  "RT @ipfconline1: The 4 Types of Artificial Intelligence: From Reactive to Self-Aware [Infographic]\n\nhttps://t.co/AgXBj9Aeir      v/ @Futuri\u2026",
#  "RT @KirkDBorne: Comprehensive Repository of #DataScience and #MachineLearning Resources, including \u201c22 Informative Articles About #NeuralNe\u2026",
#  "RT @Shavonda2016: How Executives use Social Media via #SocialCastInc \n\n#SEO #DigitalMarketing #ContentMarketing #Marketing #SMM #IoT #Growt\u2026",
#  "RT @marcusborba: Great! Simple object tracking with OpenCV\u2019s deep learning face detector (w/ Py code) https://t.co/UdOEcO5ms8 via @PyImageS\u2026",
#  "RT @SocialWiz: Where would we be without the #Internet? Scary thought! But DO YOU KNOW where the internet 'comes from'? VIA @Orcanintell\n\n#\u2026"
# ]
# [
#  "ipfconline1",
#  "KirkDBorne",
#  "Shavonda2016",
#  "marcusborba",
#  "SocialWiz"
# ]
# [
#  "DataScience",
#  "MachineLearning",
#  "SocialCastInc",
#  "SEO",
#  "DigitalMarketing"
# ]
# [
#  "RT",
# ...

# %% [markdown]
# ## Analysing Tweets ans Tweet Entities with Frequency Analysis

# %% [markdown]
# ### Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter
for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print (c.most_common()[:5]) # top 10
# Out:
# [('RT', 187), ('&gt;&gt;', 82), ('#AI', 82), ('#ArtificialIntelligence', 54), ('#MachineLearning', 51)]
# [('MikeQuindazzi', 70), ('Fisher85M', 37), ('SpirosMargaris', 13), ('ravikikan', 11), ('mclynd', 9)]
# [('AI', 85), ('ArtificialIntelligence', 55), ('DataScience', 54), ('MachineLearning', 54), ('BigData', 54)]

# %%
from collections import Counter
for item in [hashtags]:
    c = Counter(item)
    print (c.most_common()[:10]) # top 10
# Out:
# [('AI', 85), ('ArtificialIntelligence', 55), ('DataScience', 54), ('MachineLearning', 54), ('BigData', 54), ('IoT', 47), ('DeepLearning', 36), ('Blockchain', 33), ('Security', 32), ('startups', 31)]

# %% [markdown]
# ### Using prettytable to display tuples in a nice tabular format

# %% [raw]
# # install prettytable package
# conda install -c conda-forge prettytable

# %%
from prettytable import PrettyTable

# %%
for label, data in (('Word', words),
                    ('Screen Name', screen_names),
                    ('Hashtag', hashtags)):
    pt = PrettyTable(field_names=[label, 'Count'])
    c = Counter(data)
    [ pt.add_row(kv) for kv in c.most_common()[:10] ]
    pt.align[label], pt.align['Count'] = 'l', 'r' # Set column alignment
    print (pt)
# Out:
# +-------------------------+-------+
# | Word                    | Count |
# +-------------------------+-------+
# | RT                      |   187 |
# | &gt;&gt;                |    82 |
# | #AI                     |    82 |
# | #ArtificialIntelligence |    54 |
# | #MachineLearning        |    51 |
# | #BigData                |    50 |
# | #IoT                    |    47 |
# | the                     |    45 |
# | @MikeQuindazzi          |    45 |
# | &amp;                   |    44 |
# +-------------------------+-------+
# +----------------+-------+
# | Screen Name    | Count |
# +----------------+-------+
# | MikeQuindazzi  |    70 |
# | Fisher85M      |    37 |
# | SpirosMargaris |    13 |
# | ravikikan      |    11 |
# | mclynd         |     9 |
# | Ronald_vanLoon |     8 |
# | Vecto_Mobile   |     8 |
# | PwC            |     8 |
# | BristowColin   |     7 |
# | KirkDBorne     |     6 |
# +----------------+-------+
# +------------------------+-------+
# ...

# %% [markdown]
# ## Computing the Lexical Diversity of Tweets

# %% [markdown]
# ### Calculating lexical diversity for tweets

# %%
# A function for computing lexical diversity

def lexical_diversity(tokens):
    return 1.0*len(set(tokens))/len(tokens)

# %%
# A function for computing the average number of words per tweet

def average_words(statuses):
    total_words = sum([len(s.split()) for s in statuses])
    return 1.0*total_words/len(statuses)

# %%
print(lexical_diversity(words))
print(lexical_diversity(screen_names))
print(lexical_diversity(hashtags))
print(average_words(status_texts))
# Out:
# 0.23004552352048557
# 0.25872093023255816
# 0.10871905274488698
# 16.475

# %% [markdown]
# ### Examining Patterns in Retweets

# %% [markdown]
# ### Finding the most popular retweets

# %%
retweets = [(status['retweet_count'],status['retweeted_status']['user']['screen_name'], status['text'])
          
          for status in statuses
           if 'retweeted_status' in status]

# %%
# Slice off the first 5 from the sorted results and display each item in the tuple

pt = PrettyTable(field_names=['Count', 'Screen Name', 'Text'])
[ pt.add_row(row) for row in sorted(retweets, reverse=True)[:5] ]
pt.max_width['Text'] = 50
pt.align= 'l'
print (pt)
# Out:
# +-------+----------------+----------------------------------------------------+
# | Count | Screen Name    | Text                                               |
# +-------+----------------+----------------------------------------------------+
# | 288   | DeepLearn007   | RT @DeepLearn007: A Good Overview: AI, Machine     |
# |       |                | Learning &amp; The Basics Of Predictive Analytics  |
# |       |                | #AI #MachineLearning #DeepLearning #BigData #F…    |
# | 288   | DeepLearn007   | RT @DeepLearn007: A Good Overview: AI, Machine     |
# |       |                | Learning &amp; The Basics Of Predictive Analytics  |
# |       |                | #AI #MachineLearning #DeepLearning #BigData #F…    |
# | 244   | Ronald_vanLoon | RT @Ronald_vanLoon: These Dancing #Drones just     |
# |       |                | broke a world record                               |
# |       |                | by @nowthisnews |                                  |
# ...

# %% [markdown]
# ### Looking up users who have retweeted a status

# %%
# Get the original tweet id for a tweet from its retweeted_status node
# and insert it here in place of the sample value

_retweets = twitter_api.statuses.retweets(id=1023909869936623617)
print ([r['user']['screen_name'] for r in _retweets])
# Out:
# ['LuzineteDaCon13', 'akshat', 'TechfellowJp', 'fintech_paige', 'Sim_DataScience', 'ICGVCFinTech', 'Social_Molly', 'humanwareonline', 'Kre8Changesc', 'EpicRelevance', 'ChuckLSmith', 'josealvarado502', 'Harry_Robots', 'sen_taranga', 'listingwp', 'itknowingness', 'JimMarous', 'joyanand', 'xeccar', 'emilyphoon']

# %% [markdown]
# ## Visualizing Frequency Data with Histograms

# %% [markdown]
# ### Plotting frequencies of words

# %%
import matplotlib.pyplot as plt

# %%
word_counts = sorted(Counter(words).values(), reverse=True)
plt.loglog(word_counts)
plt.ylabel("Freq")
plt.xlabel("Word Rank")
# Out:
# Text(0.5,0,'Word Rank')

# %% [markdown]
# ### Generating histograms of words, screen names, and hashtags

# %%
for label, data in (('Words', words),
                    ('Screen Names', screen_names),
                    ('Hashtags', hashtags)):
# Build a frequency map for each set of data and plot the values

                    c = Counter(data)
                    plt.hist(c.values())
                    # Add a title and y-label ...
                    plt.title(label)
                    plt.ylabel("Number of items in bin")
                    plt.xlabel("Bins (number of times an item appeared)")
                    # ... and display as a new figure
                    plt.figure()

# %% [markdown]
# ### Generating a histogram of retweet counts

# %%
# Using underscores while unpacking values in a tuple is idiomatic for discarding them

counts = [count for count, _, _ in retweets]
plt.hist(counts)
plt.title("Retweets")
plt.xlabel('Bins (number of times retweeted)')
plt.ylabel('Number of tweets in bin')
print (counts)
# Out:
# [10, 80, 7, 2, 8, 4, 84, 80, 1, 4, 121, 80, 3, 2, 2, 27, 1, 80, 121, 2, 1, 1, 8, 2, 1, 4, 1, 9, 7, 80, 9, 8, 8, 1, 4, 63, 17, 8, 15, 80, 10, 32, 12, 3, 12, 19, 80, 21, 4, 13, 3, 11, 7, 18, 44, 9, 21, 19, 5, 5, 2, 19, 6, 244, 9, 6, 2, 33, 4, 1, 77, 6, 85, 12, 9, 12, 21, 4, 19, 2, 32, 7, 19, 11, 18, 288, 4, 23, 123, 21, 32, 4, 21, 15, 121, 12, 4, 12, 32, 21, 10, 4, 25, 2, 121, 4, 25, 4, 32, 32, 2, 3, 123, 5, 12, 31, 120, 33, 3, 19, 10, 6, 32, 17, 10, 32, 3, 27, 4, 2, 288, 2, 1, 4, 4, 9, 5, 5, 12, 2, 12, 15, 12, 33, 6, 165, 19, 6, 3, 44, 32, 3, 19, 24, 6, 9, 18, 3, 32, 6, 10, 13, 32, 19, 32, 19, 95, 3, 13, 2, 3, 32]

# %% [markdown]
# ## More visualization

# %%
#import operator 
from collections import Counter
from nltk.corpus import stopwords
#import string
from nltk.tokenize import word_tokenize
from nltk.tokenize import TweetTokenizer
#from os import path
#from PIL import Image
import numpy as np

# %% [raw]
# conda install -c conda-forge wordcloud

# %%
from wordcloud import WordCloud, STOPWORDS

# %% [raw]
# conda install -c conda-forge regex

# %%
import re

# %%
tweeter = pd.read_csv('tweeter.csv', encoding = "ISO-8859-1")

# %%
tweeter.head()
# Out:
#                                                tweet         names  \
# 0  RT @ipfconline1: The 4 Types of Artificial Int...   ipfconline1
# 1  RT @KirkDBorne: Comprehensive Repository of #D...    KirkDBorne
# 2  RT @Shavonda2016: How Executives use Social Me...  Shavonda2016
# 3  RT @marcusborba: Great! Simple object tracking...   marcusborba
# 4  RT @SocialWiz: Where would we be without the #...     SocialWiz
#
#             hashtag
# 0       DataScience
# 1   MachineLearning
# 2     SocialCastInc
# 3               SEO
# 4  DigitalMarketing

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Timea\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import seaborn as sns
sns.set()

# %%
top_N = 10

df = pd.read_csv('tweeter.csv', encoding = "ISO-8859-1")

txt = df.tweet.str.lower().str.replace(r'\|', ' ').str.cat(sep=' ')
words = nltk.tokenize.word_tokenize(txt)
word_dist = nltk.FreqDist(words)

stopwords = nltk.corpus.stopwords.words('english')
words_except_stop_dist = nltk.FreqDist(w for w in words if w not in stopwords) 

print('All frequencies, including STOPWORDS:')
print('=' * 60)
rslt = pd.DataFrame(word_dist.most_common(top_N),
                    columns=['Word', 'Frequency'])
print(rslt)
print('=' * 60)

rslt = pd.DataFrame(words_except_stop_dist.most_common(top_N),
                    columns=['Word', 'Frequency']).set_index('Word')


rslt.plot.bar(rot=0);
# Out:
# All frequencies, including STOPWORDS:
# ...
#     Word  Frequency
# 0      #       1041
# 1      @        353
# 2      :        307
# 3      &        216
# 4      ;        216
# 5     rt        188
# 6     gt        172
# 7     ai         92
# 8  https         90
# 9      ?         88
# ...

# %%
d = ['rt', 'RT', u'&amp;',':']

# %%
top_N = 10

df = pd.read_csv('tweet.csv', encoding = "ISO-8859-1")

stopwords = nltk.corpus.stopwords.words('english') +d
# RegEx for stopwords
RE_stopwords = r'\b(?:{})\b'.format('|'.join(stopwords))
# replace '|'-->' ' and drop all stopwords

# %%
RE_stopwords
# Out:
# "\\b(?:i|me|my|myself|we|our|ours|ourselves|you|you're|you've|you'll|you'd|your|yours|yourself|yourselves|he|him|his|himself|she|she's|her|hers|herself|it|it's|its|itself|they|them|their|theirs|themselves|what|which|who|whom|this|that|that'll|these|those|am|is|are|was|were|be|been|being|have|has|had|having|do|does|did|doing|a|an|the|and|but|if|or|because|as|until|while|of|at|by|for|with|about|against|between|into|through|during|before|after|above|below|to|from|up|down|in|out|on|off|over|under|again|further|then|once|here|there|when|where|why|how|all|any|both|each|few|more|most|other|some|such|no|nor|not|only|own|same|so|than|too|very|s|t|can|will|just|don|don't|should|should've|now|d|ll|m|o|re|ve|y|ain|aren|aren't|couldn|couldn't|didn|didn't|doesn|doesn't|hadn|hadn't|hasn|hasn't|haven|haven't|isn|isn't|ma|mightn|mightn't|mustn|mustn't|needn|needn't|shan|shan't|shouldn|shouldn't|wasn|wasn't|weren|weren't|won|won't|wouldn|wouldn't|rt|RT|&amp;|:)\\b"

# %%
words = (df.tweet
           .str.lower()
           .replace([r'\|', RE_stopwords, '&amp;', ':', '&gt;&gt;'], [' ', '','', "",''], regex=True)
           .str.cat(sep=' ')
           .split()
)

# %%
# generate DF out of Counter
word_frequency = pd.DataFrame(Counter(words).most_common(top_N), columns=['Word', 'Frequency'])

# %%
word_frequency
# Out:
#                       Word  Frequency
# 0                      #ai        102
# 1           @mikequindazzi         78
# 2                 #bigdata         67
# 3         #machinelearning         63
# 4  #artificialintelligence         49
# 5            #deeplearning         49
# 6                     #iot         48
# 7             #datascience         45
# 8                 #fintech         41
# 9                        #         34

# %%
cmap = sns.color_palette("BuGn_r", 10)
ax = sns.barplot(x='Word', y='Frequency', data=word_frequency, palette=cmap)
ax.set_xticklabels(word_frequency.Word, rotation=45)
ax.set(xlabel='word', ylabel='frequency')
ax.set_title('Word frequency in tweets')
sns.set_context("notebook", font_scale=1.5);

# %% [markdown]
# ## Word Clouds

# %% [markdown]
# ### Generating word clouds of the most frequent words in tweets

# %%
word_frequency = word_frequency.to_string(header = False)

# %%
wordcloud = WordCloud(max_font_size=50, background_color ='white', colormap = 'prism').generate(word_frequency)
plt.figure(figsize=(10,10))
plt.imshow(wordcloud, interpolation="lanczos")
plt.axis("off");

# %%
top_N = 10000

words = tweeter.hashtag

hashtag_frequency = pd.DataFrame(Counter(words).most_common(top_N), columns=['Word', 'Frequency']).set_index('Word')

# %%
hashtag_frequency.head()
# Out:
#                         Frequency
# Word
# AI                             17
# DataScience                    14
# MachineLearning                14
# ArtificialIntelligence         13
# fintech                        11

# %%
hashtag_frequency[0:15].plot.bar(rot = 90, figsize=(20,5));

# %%
hashtag_frequency = hashtag_frequency.to_string(header = False)

# %%
from scipy.misc import imread

twitter_mask = imread('./twitter_mask.png')
plt.figure(figsize=(10,10))
wordcloud = WordCloud(mask=twitter_mask, max_font_size=60, width = 800, height=400,
                      background_color ='white', colormap = 'prism').generate(hashtag_frequency)
plt.imshow(wordcloud, interpolation="lanczos")
plt.axis("off");

# %%
# Optionally, you can add additional stop words to the STOPWORD set to be ignored when building the word cloud

more_stopwords = {'oh', 'will', 'hey', 'yet', ...}
STOPWORDS = STOPWORDS.union(more_stopwords)

# %% [markdown]
# ### Creating data of relevant information

# %%
data= pd.DataFrame(data=[(status['text']) for status in statuses], columns=['Tweets'])

# %%
data.head(10)
# Out:
#                                               Tweets
# 0  RT @ipfconline1: The 4 Types of Artificial Int...
# 1  RT @KirkDBorne: Comprehensive Repository of #D...
# 2  RT @Shavonda2016: How Executives use Social Me...
# 3  RT @marcusborba: Great! Simple object tracking...
# 4  RT @SocialWiz: Where would we be without the #...
# 5  RT @AnalyticsVidhya: You'll be simply amazed t...
# 6  RT @MikeQuindazzi: The rise of intelligent ser...
# 7  RT @Ronald_vanLoon: 10 Free Must-Read Books fo...
# 8  RT @VitoshaMedia: RT @VM_Software: How Executi...
# 9  RT @MikeQuindazzi #Smartphones getting smarter...

# %%
data['Len']  = np.array([len(status['text']) for status in statuses])
data['ID']   = np.array([status['id'] for status in statuses])
data['Date'] = np.array([status['created_at'] for status in statuses])
data['Source'] = np.array([status['source'] for status in statuses])
data['Likes']  = np.array([status['favorite_count'] for status in statuses])
data['RTs']    = np.array([status['retweet_count'] for status in statuses])

# %%
data.head(10)
# Out:
#                                               Tweets  Len  \
# 0  RT @ipfconline1: The 4 Types of Artificial Int...  140
# 1  RT @KirkDBorne: Comprehensive Repository of #D...  140
# 2  RT @Shavonda2016: How Executives use Social Me...  140
# 3  RT @marcusborba: Great! Simple object tracking...  140
# 4  RT @SocialWiz: Where would we be without the #...  140
# 5  RT @AnalyticsVidhya: You'll be simply amazed t...  144
# 6  RT @MikeQuindazzi: The rise of intelligent ser...  152
# 7  RT @Ronald_vanLoon: 10 Free Must-Read Books fo...  140
# 8  RT @VitoshaMedia: RT @VM_Software: How Executi...  140
# 9  RT @MikeQuindazzi #Smartphones getting smarter...  152
#
#                     ID                            Date  \
# 0  1025703862143995905  Sat Aug 04 11:23:52 +0000 2018
# 1  1025703841445097473  Sat Aug 04 11:23:47 +0000 2018
# 2  1025703785493131264  Sat Aug 04 11:23:33 +0000 2018
# 3  1025703779650478082  Sat Aug 04 11:23:32 +0000 2018
# ...

# %%
source = data['Source'].str.replace(r'<(?:a\b[^>]*>|/a>)',' ')
source = pd.DataFrame(source)
data['source'] = source
data.head()
# Out:
#                                               Tweets  Len  \
# 0  RT @ipfconline1: The 4 Types of Artificial Int...  140
# 1  RT @KirkDBorne: Comprehensive Repository of #D...  140
# 2  RT @Shavonda2016: How Executives use Social Me...  140
# 3  RT @marcusborba: Great! Simple object tracking...  140
# 4  RT @SocialWiz: Where would we be without the #...  140
#
#                     ID                            Date  \
# 0  1025703862143995905  Sat Aug 04 11:23:52 +0000 2018
# 1  1025703841445097473  Sat Aug 04 11:23:47 +0000 2018
# 2  1025703785493131264  Sat Aug 04 11:23:33 +0000 2018
# 3  1025703779650478082  Sat Aug 04 11:23:32 +0000 2018
# 4  1025703763187847168  Sat Aug 04 11:23:28 +0000 2018
#
#                                               Source  Likes  RTs  \
# 0  <a href="http://twitter.com/download/iphone" r...      0   10
# 1  <a href="http://twitter.com/#!/download/ipad" ...      0   80
# 2  <a href="http://twitter.com/#!/download/ipad" ...      0    7
# ...

# %%
fav_max = np.max(data['Likes'])
rt_max  = np.max(data['RTs'])

# %%
fav = data[data.Likes == fav_max].index[0]
rt  = data[data.RTs == rt_max].index[0]

# %%
# Max FAVs
print("The tweet with more likes is: \n{}".format(data['Tweets'][fav]))
print("Number of likes: {}".format(fav_max))
print("{} characters.\n".format(data['Len'][fav]))

# Max RTs
print("The tweet with more retweets is: \n{}".format(data['Tweets'][rt]))
print("Number of retweets: {}".format(rt_max))
print("{} characters.\n".format(data['Len'][rt]))
# Out:
# The tweet with more likes is:
# Eras #Blockchain &amp; #Bitcoin
#
# #FinTech #IoT #SmartCity #startups #APIs #Security @Fisher85M #DataScience #BigData… https://t.co/Aq3DGSNywe
# Number of likes: 3
# 142 characters.
#
# The tweet with more retweets is:
# RT @DeepLearn007: A Good Overview: AI, Machine Learning &amp; The Basics Of Predictive Analytics
# #AI #MachineLearning #DeepLearning #BigData #F…
# Number of retweets: 288
# 144 characters.

# %% [markdown]
# ## Time series

# %%
# Create time series for data

tlen = pd.Series(data=data['Len'].values, index=data['Date'])
tfav = pd.Series(data=data['Likes'].values, index=data['Date'])
tret = pd.Series(data=data['RTs'].values, index=data['Date'])

# %%
tlen.plot(figsize=(12,4), color='r', rot=45);

# %%
# Likes vs retweets visualization

tfav.plot(label="Likes", legend=True, rot=45)
tret.plot(label="Retweets", legend=True, rot=45);

# %%
tfav.plot(label="Likes", legend=True, rot=45);

# %%
# Obtaining all possible sources
sources = []
for source in data['source']:
    if source not in sources:
        sources.append(source)

# %%
# print sources list
print("Creation of content sources:")
for source in sources:
    print("* {}".format(source))
# Out:
# Creation of content sources:
# *  Twitter for iPhone
# *  Twitter for iPad
# *  Twitter for Android
# *  AdaBox1
# *  Twitter Web Client
# *  Machine Learning Digest
# *  Buffer
# *  Data science bot news 1
# *  inter discipl
# *  machine learn bot 10
# *  Blockchains
# *  BizDir1
# *  jen_tyrell
# *  ttools it knowingness
# *  taylor_levi
# *  Applied AI
# *  TheBigDataBot
# *  auto is the only way it can be
# *  blockjn
# *  sakurabaaa_g
# *  thancmar_feldt
# *  sisSoftware
# *  micha_vino
# *  new-app-test
# *  james_fletcher
# *  Twitter Lite
# *  beatrice_kraus
# *  Hootsuite Inc.
# *  Microsoft PowerApps and Flow
# *  Tweetbot for iΟS
# *  Aldo Zaffalon
# *  IFTTT
# *  Elecciones Mexico App
# *  sam_roy
# *  nkruma_ignatov
# *  matxanh
# *  RoundTeam
# *  DME Intelligence Jul
# *  datadrivencare_helper
# *  fb_bot
# *  CoderBotNg
# *  mallory_wechsler
# *  Simple Tutorial Blog
# *  TweetDeck
# *  Retweet Inbound
# *  Myriam_BAI_twitter_bot

# %% [raw]
# # Creating a numpy vector mapped to labels:
# percent = np.zeros(len(sources))
#
# for source in data['source']:
#     for index in range(len(sources)):
#         if source == sources[index]:
#             percent[index] += 1
#             pass
#
# percent /= 100
#
# # Pie chart:
# pie_chart = pd.Series(percent, index=sources, name='Sources')
# pie_chart.plot.pie(fontsize=11, autopct='%.2f', figsize=(12, 12));

# %%
data.source.value_counts().plot(kind="bar", figsize=(15,3));

# %% [markdown]
# ### Sentiment analysis

# %% [raw]
# conda install -c conda-forge textblob

# %%
from textblob import TextBlob
import re

def clean_tweet(tweet):
    '''
    Utility function to clean the text in a tweet by removing 
    links and special characters using regex.
    '''
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

def analize_sentiment(tweet):
    '''
    Utility function to classify the polarity of a tweet
    using textblob.
    '''
    analysis = TextBlob(clean_tweet(tweet))
    if analysis.sentiment.polarity > 0:
        return 1
    elif analysis.sentiment.polarity == 0:
        return 0
    else:
        return -1

# %%
# Creating a column with the result of the analysis
data['SA'] = np.array([ analize_sentiment(tweet) for tweet in data['Tweets'] ])

# Displaying the updated dataframe with the new column
display(data.head(10))
# Out:
#                                               Tweets  Len  \
# 0  RT @ipfconline1: The 4 Types of Artificial Int...  140
# 1  RT @KirkDBorne: Comprehensive Repository of #D...  140
# 2  RT @Shavonda2016: How Executives use Social Me...  140
# 3  RT @marcusborba: Great! Simple object tracking...  140
# 4  RT @SocialWiz: Where would we be without the #...  140
# 5  RT @AnalyticsVidhya: You'll be simply amazed t...  144
# 6  RT @MikeQuindazzi: The rise of intelligent ser...  152
# 7  RT @Ronald_vanLoon: 10 Free Must-Read Books fo...  140
# 8  RT @VitoshaMedia: RT @VM_Software: How Executi...  140
# 9  RT @MikeQuindazzi #Smartphones getting smarter...  152
#
#                     ID                            Date  \
# 0  1025703862143995905  Sat Aug 04 11:23:52 +0000 2018
# 1  1025703841445097473  Sat Aug 04 11:23:47 +0000 2018
# 2  1025703785493131264  Sat Aug 04 11:23:33 +0000 2018
# 3  1025703779650478082  Sat Aug 04 11:23:32 +0000 2018
# ...

# %%
# Constructing lists with classified tweets

pos_tweets = [ tweet for index, tweet in enumerate(data['Tweets']) if data['SA'][index] > 0]
neu_tweets = [ tweet for index, tweet in enumerate(data['Tweets']) if data['SA'][index] == 0]
neg_tweets = [ tweet for index, tweet in enumerate(data['Tweets']) if data['SA'][index] < 0]

# %%
# Printing percentages

print("Percentage of positive tweets: {}%".format(len(pos_tweets)*100/len(data['Tweets'])))
print("Percentage of neutral tweets: {}%".format(len(neu_tweets)*100/len(data['Tweets'])))
print("Percentage de negative tweets: {}%".format(len(neg_tweets)*100/len(data['Tweets'])))
# Out:
# Percentage of positive tweets: 40.0%
# Percentage of neutral tweets: 49.5%
# Percentage de negative tweets: 10.5%

# %%
data['sentiment'] = data.SA

# %%
data['sentiment'].replace([0,1,-1],['neutral','positive','negative'],inplace=True)

# %%
data.head()
# Out:
#                                               Tweets  Len  \
# 0  RT @ipfconline1: The 4 Types of Artificial Int...  140
# 1  RT @KirkDBorne: Comprehensive Repository of #D...  140
# 2  RT @Shavonda2016: How Executives use Social Me...  140
# 3  RT @marcusborba: Great! Simple object tracking...  140
# 4  RT @SocialWiz: Where would we be without the #...  140
#
#                     ID                            Date  \
# 0  1025703862143995905  Sat Aug 04 11:23:52 +0000 2018
# 1  1025703841445097473  Sat Aug 04 11:23:47 +0000 2018
# 2  1025703785493131264  Sat Aug 04 11:23:33 +0000 2018
# 3  1025703779650478082  Sat Aug 04 11:23:32 +0000 2018
# 4  1025703763187847168  Sat Aug 04 11:23:28 +0000 2018
#
#                                               Source  Likes  RTs  \
# 0  <a href="http://twitter.com/download/iphone" r...      0   10
# 1  <a href="http://twitter.com/#!/download/ipad" ...      0   80
# 2  <a href="http://twitter.com/#!/download/ipad" ...      0    7
# ...

# %%
data.groupby('sentiment')['sentiment'].count()
# Out:
# sentiment
# negative    21
# neutral     99
# positive    80
# Name: sentiment, dtype: int64

# %%
explode = (0.05, 0.05, 0.05)
colors = ['red','blue','green']
data.groupby('sentiment')['sentiment'].count().plot(kind='pie', explode=explode,  autopct='%1.1f%%',
                                                    shadow=True, startangle=90, colors = colors)
plt.axis('equal');
